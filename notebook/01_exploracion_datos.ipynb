# %%
#!pip install datasets
from datasets import load_dataset

# %%
#%pip install --upgrade datasets fsspec
# Out:
# ...
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# ...

# %%
from datasets import get_dataset_config_names
pairs = get_dataset_config_names("wmt14")
print(pairs)
# Out:
# ['cs-en', 'de-en', 'fr-en', 'hi-en', 'ru-en']

# %%
dataset = load_dataset("wmt14", "de-en")
print(dataset)
# Out:
# train-00000-of-00003.parquet:   0%|          | 0.00/280M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/265M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/273M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/474k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/509k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/3003 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 4508785
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 3003
#     })
# })

# %%
import pandas as pd
train_data = dataset["train"]
examples = [{"de": ex["translation"]["de"], "en": ex["translation"]["en"]} for ex in train_data.select(range(10))]
df = pd.DataFrame(examples)
df.head()
# Out:
#                                                   de  \
# 0                 Wiederaufnahme der Sitzungsperiode
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                                   en
# 0                          Resumption of the session
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...

# %%
print(f"Tamaño del vocabulario (muestra): {len(set(word for ex in train_data for word in ex['translation']['en'].split()))}")
# Out:
# Tamaño del vocabulario (muestra): 1898504
